# %%
import cv2
import torch
import numpy as np
import time
import torch
from ultralytics import YOLO

# %%
# # Clona el repositorio de YOLOv5
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5

# # Instala las dependencias
# !pip install -r requirements.txt

# %% [markdown]
# ## 1. Load YOLO Object Detector

# %%
# Cargar el modelo YOLOv5
# model1 = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# model2 = torch.hub.load('ultralytics/yolov5', 'yolov5n', pretrained=True)
# model3 = torch.load('C:/Users/mirvi/Desktop/mii/UAB/4.1/PSIV2/detect mateicules/repte2_psiv2/object_tracking_yolo/yolov8n.pt')
model3 = YOLO('C:/Users/mirvi/Desktop/mii/UAB/4.1/PSIV2/detect mateicules/repte2_psiv2/object_tracking_yolo/yolov8n.pt')

print(type(model3))

# Definir clases de interés
CLASSES_OF_INTEREST = ['car']
# Out:
# <class 'ultralytics.models.yolo.model.YOLO'>

# %% [markdown]
# ## 2. Define Tracker Class (per centroides)

# %%
import numpy as np
from scipy.spatial.distance import cdist

class Tracker:
    MAX_DISAPPEAR_LIMIT = 14
    def __init__(self,res_p=1):
        self.next_unique_id = 0
        self.trackers = {}
        self.disappear_trackers = {}
        self.tracked_bboxes = {}
        self.MAX_DISTANCE_THRESHOLD = 200*res_p
    
    
    def init_object(self,centroid,boxes):
        global next_unique_id
        self.trackers[self.next_unique_id] = centroid
        self.tracked_bboxes[self.next_unique_id] = boxes
        self.disappear_trackers[self.next_unique_id] = 0
        self.next_unique_id+=1

    def del_object(self,track_id):
        del self.trackers[track_id]
        del self.tracked_bboxes[track_id]
        del self.disappear_trackers[track_id]

    def update_object(self,bboxes):
        
        if(len(bboxes)==0):
            
            for oid in list(self.disappear_trackers.keys()):
                self.disappear_trackers[oid]+=1
                
                if self.disappear_trackers[oid] > Tracker.MAX_DISAPPEAR_LIMIT:
                    self.del_object(oid)
                
            return self.tracked_bboxes
        
        else:   
            input_centroids = np.zeros((len(bboxes),2)) 
            for i in range(len(bboxes)):
                x,y,w,h = bboxes[i][0],bboxes[i][1],bboxes[i][2],bboxes[i][3]
                cx,cy = x + w/2 , y + h/2
                input_centroids[i] = (cx,cy)

            
            if(len(self.trackers)==0):
                for i in range(len(input_centroids)):
                    self.init_object(input_centroids[i],bboxes[i])
            
            else:
                
                tracker_centroids = list(self.trackers.values())

                distance_matrix = cdist(np.array(tracker_centroids) , input_centroids)

                rows = distance_matrix.min(axis=1).argsort()
                cols = distance_matrix.argmin(axis=1)[rows]

                usedRows = set()
                usedCols = set()
                
                tracker_ids = list(self.trackers.keys()) 
                for row,col in zip(rows,cols):
                    if row in usedRows or col in usedCols:
                        continue

                    # # Check if distance is within the threshold of 200 pixels
                    # if distance_matrix[row, col] > self.MAX_DISTANCE_THRESHOLD:
                    #     continue  # Skip association if distance is too large

                    track_id = tracker_ids[row]
                    
                    self.trackers[track_id] = input_centroids[col]
                    self.tracked_bboxes[track_id] = bboxes[col]

                    self.disappear_trackers[track_id] = 0
                    usedRows.add(row)                                
                    usedCols.add(col)

                unusedRows = set(range(0,distance_matrix.shape[0])).difference(usedRows)
                unusedCols = set(range(0,distance_matrix.shape[1])).difference(usedCols)

                if(distance_matrix.shape[0]>=distance_matrix.shape[1]):
                    
                    for r in unusedRows: 
                        track_id = tracker_ids[r]
                        self.disappear_trackers[track_id]+=1
                        if(self.disappear_trackers[track_id] > Tracker.MAX_DISAPPEAR_LIMIT):
                            self.del_object(track_id)
                else:
                    for c in unusedCols:                    
                        self.init_object(input_centroids[c],bboxes[c])

        return self.tracked_bboxes

# %% [markdown]
# ## 3. Load Video

# %%
# resize percent
resize_percent = 0.7

cap = cv2.VideoCapture("/Users/mirvi/Desktop/mii/UAB/4.1/PSIV2/detect mateicules/repte2_psiv2/data_r2/short_uab_flow.mp4")

# %% [markdown]
# ## 4. Object Detection and Tracking over video

# %%
# PROCESS VIDEO IN GRAYSCALE
gray_video_og = []

i=0
while True:
    ret, fr = cap.read()
    if not ret:
        break
    # resize frame
    fr = cv2.resize(fr, (0, 0), fx=resize_percent, fy=resize_percent)

    # # to gray
    # fr2 = cv2.cvtColor(fr1, cv2.COLOR_BGR2GRAY)

    # # apply clahe contrast
    # clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    # fr = clahe.apply(fr2)

    # agafar nomes frames que volem
    if i>0:
        gray_video_og.append(fr)
    # if i == 3200:
    #     break
    i+=1

print(i)
# Out:
# 7288

# %%
import time
import cv2

time_start_all = time.time()

# Define selected model
model = model3

# Init tracker
tracker2 = Tracker(res_p=resize_percent)

# Define ROI dimensions
roix1 = int(150 * resize_percent)
roix2 = int(480 * resize_percent)
roiy1 = int(340 * resize_percent)
roiy2 = int(800 * resize_percent)

# Define reference line in the middle of the ROI
line_y_position = ((roiy2 - roiy1) // 2) - int(40 * resize_percent)

# Counters for cars moving up and down
count_up = 0
count_down = 0

# Dictionary to store previous positions of each car
previous_positions = {}

# Dictionary to track crossed status
crossed_up = {id: False for id in range(200)}
crossed_down = {id: False for id in range(200)}
parked = {id: False for id in range(200)}

# Distance threshold for movement in pixels
movement_threshold = 50*resize_percent

# Initialize last positions dictionary
last_positions = {}

frame_id = 0

# init box_id var
box_id = 0

# right roi margin
right_margin = 35*resize_percent


while frame_id < len(gray_video_og) - 1:
    # Start time measurement
    time_start = time.time()

    # Process the frame
    fr = gray_video_og[frame_id]
    frame = fr.copy()
    height, width, _ = frame.shape

    # Extract ROI
    roi = frame[roiy1:roiy2, roix1:roix2]

    # 1. Object Detection
    ts_od = time.time()
    results = model(roi)

    # Filter detections based on size and movement
    detections = []
    for idx,det in enumerate(results[0].boxes):
        x1, y1, x2, y2, conf, cls = det.data[0]
        if cls == 2:
            w = int(x2 - x1)
            h = int(y2 - y1)
            x = int(x1)
            y = int(y1)

            # Only keep detections with a certain size
            if w > 55 * resize_percent and h > 55 * resize_percent:
                detections.append([x, y, w, h])

    te_od = time.time()

    # Draw text and ROI with reference line
    cv2.putText(frame, f'ObjDet time: {(te_od - ts_od):.2f}', 
                (int(10 * resize_percent), int(30 * resize_percent)), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2)
    print('count up:', count_up)
    cv2.putText(frame, f"UP: {count_up}", (int(10 * resize_percent), int(700 * resize_percent)), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"DOWN: {count_down}", (int(10 * resize_percent), int(750 * resize_percent)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.rectangle(frame, (roix1, roiy1), (roix2, roiy2), (0, 255, 125), 2)

    # Draw line with increments
    line_inc = [-100, 0, 100]
    for inc in line_inc:
        cv2.line(roi, (0, line_y_position + inc), (width, line_y_position + inc), (0, 255, 255), 2)

    # 2. Object Tracking
    boxes_ids = tracker2.update_object(detections)

    # Draw bounding boxes and text for tracked objects
    for box_id, box in boxes_ids.items():
        x, y, w, h = box
        id = box_id

        # check if car is parked
        if x + w + roix1 > roix2 - right_margin:
            crossed_up[id] = True
            crossed_down[id] = True
            parked[id] = True

        # Draw ID and bounding box
        if parked[id]:
            cv2.putText(roi, f"PARKED {str(id)}", (x, y - 10), cv2.FONT_HERSHEY_PLAIN, 0.7, (255, 127, 0), 2)
            cv2.rectangle(roi, (x, y), (x + w, y + h), (200, 0, 255), 2)
        else:
            cv2.putText(roi, str(id), (x, y - 10), cv2.FONT_HERSHEY_PLAIN, 0.7, (255, 127, 0), 2)
            cv2.rectangle(roi, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Check if the car crossed the line
        current_y = y + h // 2
        if id not in previous_positions:
            previous_positions[id] = current_y
            continue

        previous_y = previous_positions[id]

        # Check if object has not yet crossed any line
        if not crossed_up[id] and not crossed_down[id]:
            for inc in line_inc:
                # Check crossing of reference line
                if previous_y < line_y_position + int(inc * resize_percent) and current_y > line_y_position + int(inc * resize_percent) and not crossed_down[id]:
                    count_down += 1
                    # cv2.putText(frame, f"DOWN: {count_down}", (int(10 * resize_percent), int(750 * resize_percent)), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)
                    crossed_down[id] = True
                    break
                elif previous_y > line_y_position and current_y < line_y_position and not crossed_up[id]:
                    count_up += 1
                    # cv2.putText(frame, f"UP: {count_up}", (int(10 * resize_percent), int(750 * resize_percent)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                    crossed_up[id] = True
                    break

        # Update the car's previous position
        previous_positions[id] = current_y

    # Calculate FPS
    time_end = time.time()
    time_per_frame = time_end - time_start
    fps = 1 / time_per_frame if time_per_frame > 0 else 0
    cv2.putText(frame, f'Processing time: {fps:.2f} FPS', (10, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 0), 2)

    # Show frames
    cv2.imshow("roi", roi)
    cv2.imshow("Frame", frame)

    # Advance frame
    frame_id += 7

    # Exit with ESC key
    if cv2.waitKey(30) == 27:
        break

time_end_all = time.time()

cap.release()
cv2.destroyAllWindows()

print('count up:', count_up)
print('count down:', count_down)
# Out:
# 0: 640x480 2 cars, 1 remote, 604.4ms
# Speed: 107.8ms preprocess, 604.4ms inference, 59.8ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 remote, 300.2ms
# Speed: 14.0ms preprocess, 300.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 remote, 250.3ms
# Speed: 12.0ms preprocess, 250.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 remote, 236.4ms
# Speed: 9.0ms preprocess, 236.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 remote, 259.3ms
# Speed: 7.0ms preprocess, 259.3ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 5 cars, 1 remote, 241.4ms
# Speed: 6.0ms preprocess, 241.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 4 cars, 1 remote, 210.4ms
# Speed: 5.0ms preprocess, 210.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 remote, 224.4ms
# Speed: 8.0ms preprocess, 224.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 remote, 218.4ms
# Speed: 8.0ms preprocess, 218.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 232.4ms
# Speed: 59.8ms preprocess, 232.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 2 cars, 1 remote, 172.5ms
# Speed: 6.0ms preprocess, 172.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 2 cars, 1 remote, 165.6ms
# Speed: 6.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 176.5ms
# Speed: 5.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 163.6ms
# Speed: 6.0ms preprocess, 163.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 truck, 182.5ms
# Speed: 5.0ms preprocess, 182.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 165.6ms
# Speed: 5.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 175.5ms
# Speed: 5.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 truck, 174.5ms
# Speed: 7.0ms preprocess, 174.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 172.5ms
# Speed: 5.0ms preprocess, 172.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 172.5ms
# Speed: 5.0ms preprocess, 172.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 165.6ms
# Speed: 4.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 166.6ms
# Speed: 6.0ms preprocess, 166.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 1 remote, 164.6ms
# Speed: 4.0ms preprocess, 164.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 0
#
# 0: 640x480 3 cars, 165.6ms
# Speed: 5.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 177.5ms
# Speed: 7.0ms preprocess, 177.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 163.6ms
# Speed: 5.0ms preprocess, 163.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 168.5ms
# Speed: 4.0ms preprocess, 168.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 167.5ms
# Speed: 5.0ms preprocess, 167.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 167.5ms
# Speed: 7.0ms preprocess, 167.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 171.5ms
# Speed: 5.0ms preprocess, 171.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 253.3ms
# Speed: 5.0ms preprocess, 253.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 168.6ms
# Speed: 5.0ms preprocess, 168.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 176.5ms
# Speed: 7.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 175.5ms
# Speed: 7.0ms preprocess, 175.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 170.5ms
# Speed: 5.0ms preprocess, 170.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 253.3ms
# Speed: 32.9ms preprocess, 253.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 153.6ms
# Speed: 4.0ms preprocess, 153.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 153.6ms
# Speed: 7.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 152.6ms
# Speed: 4.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 145.6ms
# Speed: 7.0ms preprocess, 145.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 153.6ms
# Speed: 4.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 154.6ms
# Speed: 4.0ms preprocess, 154.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 153.6ms
# Speed: 6.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 154.6ms
# Speed: 4.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 161.6ms
# Speed: 6.0ms preprocess, 161.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 158.6ms
# Speed: 5.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 155.6ms
# Speed: 7.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 154.6ms
# Speed: 4.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 153.6ms
# Speed: 4.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 155.6ms
# Speed: 5.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 1 person, 3 cars, 1 remote, 147.6ms
# Speed: 4.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 155.6ms
# Speed: 6.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 230.4ms
# Speed: 17.0ms preprocess, 230.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 151.6ms
# Speed: 4.0ms preprocess, 151.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 154.6ms
# Speed: 6.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 164.6ms
# Speed: 5.0ms preprocess, 164.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 158.6ms
# Speed: 6.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 163.6ms
# Speed: 5.0ms preprocess, 163.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 174.5ms
# Speed: 4.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 146.6ms
# Speed: 6.0ms preprocess, 146.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 1 person, 3 cars, 1 remote, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 1 person, 3 cars, 1 remote, 180.5ms
# Speed: 7.0ms preprocess, 180.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 155.6ms
# Speed: 6.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 147.6ms
# Speed: 6.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 174.5ms
# Speed: 5.0ms preprocess, 174.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 161.6ms
# Speed: 7.0ms preprocess, 161.6ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 285.2ms
# Speed: 4.0ms preprocess, 285.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 1 person, 3 cars, 1 remote, 155.6ms
# Speed: 6.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 1 person, 3 cars, 1 remote, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 1 person, 3 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 1 person, 3 cars, 1 remote, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 160.6ms
# Speed: 6.0ms preprocess, 160.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 155.6ms
# Speed: 5.0ms preprocess, 155.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 158.6ms
# Speed: 5.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 148.6ms
# Speed: 4.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 159.6ms
# Speed: 6.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 1 remote, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 156.6ms
# Speed: 6.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 275.3ms
# Speed: 5.0ms preprocess, 275.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 158.6ms
# Speed: 5.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 153.6ms
# Speed: 6.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 146.6ms
# Speed: 5.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 truck, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 4 cars, 183.5ms
# Speed: 7.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 truck, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 155.6ms
# Speed: 5.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 truck, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 2 cars, 1 truck, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 truck, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 3 cars, 1 truck, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 4 cars, 160.6ms
# Speed: 5.0ms preprocess, 160.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 1
#
# 0: 640x480 4 cars, 1 truck, 150.6ms
# Speed: 7.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 157.6ms
# Speed: 4.0ms preprocess, 157.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 277.3ms
# Speed: 5.0ms preprocess, 277.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 160.6ms
# Speed: 8.0ms preprocess, 160.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 156.6ms
# Speed: 4.0ms preprocess, 156.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 153.6ms
# Speed: 7.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 158.6ms
# Speed: 4.0ms preprocess, 158.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 156.6ms
# Speed: 6.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 149.6ms
# Speed: 6.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 152.6ms
# Speed: 4.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 151.6ms
# Speed: 4.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 146.6ms
# Speed: 6.0ms preprocess, 146.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 154.6ms
# Speed: 4.0ms preprocess, 154.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 151.6ms
# Speed: 7.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 4 cars, 1 remote, 162.6ms
# Speed: 5.0ms preprocess, 162.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 184.5ms
# Speed: 5.0ms preprocess, 184.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 234.4ms
# Speed: 42.9ms preprocess, 234.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 150.6ms
# Speed: 7.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 155.6ms
# Speed: 5.0ms preprocess, 155.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 155.6ms
# Speed: 5.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 158.6ms
# Speed: 6.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 153.6ms
# Speed: 6.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 160.6ms
# Speed: 6.0ms preprocess, 160.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 271.3ms
# Speed: 5.0ms preprocess, 271.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 156.6ms
# Speed: 6.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 146.6ms
# Speed: 5.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 187.5ms
# Speed: 5.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 145.6ms
# Speed: 6.0ms preprocess, 145.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 143.6ms
# Speed: 5.0ms preprocess, 143.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 158.6ms
# Speed: 4.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 153.6ms
# Speed: 6.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 7.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 155.6ms
# Speed: 5.0ms preprocess, 155.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 155.6ms
# Speed: 4.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 148.6ms
# Speed: 8.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 247.3ms
# Speed: 24.9ms preprocess, 247.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 6.0ms preprocess, 149.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 155.6ms
# Speed: 6.0ms preprocess, 155.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 156.6ms
# Speed: 4.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 156.6ms
# Speed: 20.9ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 146.6ms
# Speed: 5.0ms preprocess, 146.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 143.6ms
# Speed: 4.0ms preprocess, 143.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 152.6ms
# Speed: 4.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 156.6ms
# Speed: 7.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 155.6ms
# Speed: 6.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 155.6ms
# Speed: 6.0ms preprocess, 155.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 141.6ms
# Speed: 6.0ms preprocess, 141.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 146.6ms
# Speed: 4.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 231.4ms
# Speed: 42.9ms preprocess, 231.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 155.6ms
# Speed: 6.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 158.6ms
# Speed: 5.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 154.6ms
# Speed: 6.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 177.5ms
# Speed: 5.0ms preprocess, 177.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 150.6ms
# Speed: 4.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 158.6ms
# Speed: 6.0ms preprocess, 158.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 161.6ms
# Speed: 4.0ms preprocess, 161.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 155.6ms
# Speed: 4.0ms preprocess, 155.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 149.6ms
# Speed: 6.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 274.3ms
# Speed: 5.0ms preprocess, 274.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 1 person, 3 cars, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 1 person, 3 cars, 1 remote, 185.5ms
# Speed: 6.0ms preprocess, 185.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 150.6ms
# Speed: 4.0ms preprocess, 150.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 persons, 3 cars, 1 remote, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 1 person, 3 cars, 153.6ms
# Speed: 7.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 153.6ms
# Speed: 6.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 1 person, 3 cars, 157.6ms
# Speed: 4.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 159.6ms
# Speed: 6.0ms preprocess, 159.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 1 person, 3 cars, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 154.6ms
# Speed: 7.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 1 person, 3 cars, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 164.6ms
# Speed: 6.0ms preprocess, 164.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 162.6ms
# Speed: 5.0ms preprocess, 162.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 146.6ms
# Speed: 6.0ms preprocess, 146.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 145.6ms
# Speed: 5.0ms preprocess, 145.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 158.6ms
# Speed: 5.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 171.5ms
# Speed: 6.0ms preprocess, 171.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 179.5ms
# Speed: 5.0ms preprocess, 179.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 176.5ms
# Speed: 4.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 176.5ms
# Speed: 7.0ms preprocess, 176.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 156.6ms
# Speed: 11.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 3 cars, 1 remote, 277.3ms
# Speed: 5.0ms preprocess, 277.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 146.6ms
# Speed: 5.0ms preprocess, 146.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 157.6ms
# Speed: 4.0ms preprocess, 157.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 156.6ms
# Speed: 6.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 164.6ms
# Speed: 5.0ms preprocess, 164.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 150.6ms
# Speed: 7.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 148.6ms
# Speed: 4.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 7.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 146.6ms
# Speed: 4.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 173.5ms
# Speed: 5.0ms preprocess, 173.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 172.5ms
# Speed: 7.0ms preprocess, 172.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 173.5ms
# Speed: 5.0ms preprocess, 173.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 155.6ms
# Speed: 4.0ms preprocess, 155.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 259.3ms
# Speed: 5.0ms preprocess, 259.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 159.6ms
# Speed: 4.0ms preprocess, 159.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 154.6ms
# Speed: 4.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 3.0ms preprocess, 151.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 169.5ms
# Speed: 17.0ms preprocess, 169.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 142.6ms
# Speed: 6.0ms preprocess, 142.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 147.6ms
# Speed: 6.0ms preprocess, 147.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 1 remote, 149.6ms
# Speed: 6.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 154.6ms
# Speed: 4.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 151.6ms
# Speed: 4.0ms preprocess, 151.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 158.6ms
# Speed: 6.0ms preprocess, 158.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 2
#
# 0: 640x480 2 cars, 155.6ms
# ...
# count up: 4
#
# 0: 640x480 1 car, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 158.6ms
# Speed: 5.0ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 274.3ms
# Speed: 6.0ms preprocess, 274.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 184.5ms
# Speed: 5.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 161.6ms
# Speed: 5.0ms preprocess, 161.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 157.6ms
# Speed: 7.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 161.6ms
# Speed: 4.0ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 152.6ms
# Speed: 7.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 159.6ms
# Speed: 6.0ms preprocess, 159.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 187.5ms
# Speed: 7.0ms preprocess, 187.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 151.6ms
# Speed: 4.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 183.5ms
# Speed: 5.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 270.3ms
# Speed: 6.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 153.6ms
# Speed: 4.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 157.6ms
# Speed: 7.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 194.5ms
# Speed: 4.0ms preprocess, 194.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 156.6ms
# Speed: 7.0ms preprocess, 156.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 remote, 176.5ms
# Speed: 7.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 1 chair, 149.6ms
# Speed: 7.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 1 car, 187.5ms
# Speed: 8.0ms preprocess, 187.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 1 truck, 156.6ms
# Speed: 6.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 158.6ms
# Speed: 19.9ms preprocess, 158.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 155.6ms
# Speed: 7.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 1 truck, 235.4ms
# Speed: 39.9ms preprocess, 235.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 160.6ms
# Speed: 5.0ms preprocess, 160.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 1 truck, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 152.6ms
# Speed: 6.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 4
#
# 0: 640x480 2 cars, 189.5ms
# Speed: 5.0ms preprocess, 189.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 150.6ms
# Speed: 7.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 1 remote, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 178.5ms
# Speed: 4.0ms preprocess, 178.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 1 remote, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 1 remote, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 154.6ms
# Speed: 5.0ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 3 cars, 184.5ms
# Speed: 4.0ms preprocess, 184.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 1 remote, 144.6ms
# Speed: 5.0ms preprocess, 144.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 2 remotes, 153.6ms
# Speed: 5.0ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 159.6ms
# Speed: 4.0ms preprocess, 159.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 211.4ms
# Speed: 44.9ms preprocess, 211.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 1 remote, 195.5ms
# Speed: 4.0ms preprocess, 195.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 2 remotes, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 150.6ms
# Speed: 6.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 persons, 2 cars, 1 remote, 146.6ms
# Speed: 4.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 144.6ms
# Speed: 4.0ms preprocess, 144.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 152.6ms
# Speed: 8.0ms preprocess, 152.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 1 remote, 183.5ms
# Speed: 6.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 1 remote, 148.6ms
# Speed: 5.0ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 1 remote, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 1 remote, 146.6ms
# Speed: 5.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 184.5ms
# Speed: 5.0ms preprocess, 184.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 151.6ms
# Speed: 5.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 2 remotes, 149.6ms
# Speed: 4.0ms preprocess, 149.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 2 cars, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 3 cars, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 193.5ms
# Speed: 4.0ms preprocess, 193.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 279.2ms
# Speed: 7.0ms preprocess, 279.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 4 cars, 155.6ms
# Speed: 7.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 149.6ms
# Speed: 5.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 147.6ms
# Speed: 6.0ms preprocess, 147.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 224.4ms
# Speed: 5.0ms preprocess, 224.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 355.1ms
# Speed: 18.0ms preprocess, 355.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 156.6ms
# Speed: 5.0ms preprocess, 156.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 151.6ms
# Speed: 4.0ms preprocess, 151.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 2 cars, 155.6ms
# Speed: 7.0ms preprocess, 155.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 1 person, 3 cars, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 5
#
# 0: 640x480 3 cars, 1 truck, 185.5ms
# Speed: 5.0ms preprocess, 185.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 146.6ms
# Speed: 6.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 152.6ms
# Speed: 4.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 1 remote, 157.6ms
# Speed: 5.0ms preprocess, 157.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 1 truck, 1 remote, 167.6ms
# Speed: 7.0ms preprocess, 167.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 167.5ms
# Speed: 5.0ms preprocess, 167.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 187.5ms
# Speed: 4.0ms preprocess, 187.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 152.6ms
# Speed: 5.0ms preprocess, 152.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 147.6ms
# Speed: 5.0ms preprocess, 147.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 4 cars, 1 remote, 161.6ms
# Speed: 5.0ms preprocess, 161.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 5 cars, 148.6ms
# Speed: 4.0ms preprocess, 148.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 2 cars, 146.6ms
# Speed: 6.0ms preprocess, 146.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 4 cars, 1 remote, 183.5ms
# Speed: 4.0ms preprocess, 183.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 241.4ms
# Speed: 13.0ms preprocess, 241.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 4 cars, 148.6ms
# Speed: 6.0ms preprocess, 148.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
#
# 0: 640x480 3 cars, 150.6ms
# Speed: 5.0ms preprocess, 150.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
# count up: 6
# count up: 6
# count down: 2

# %% [markdown]
# ## CALCUL TEMPS FINAL
